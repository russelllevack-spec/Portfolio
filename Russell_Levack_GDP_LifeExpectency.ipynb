# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

data = pd.read_csv("all_data.csv")

print(data.info(), data.describe(), data.columns)
print(data.groupby('Country').mean())

data['log_GDP'] = np.log10(data.GDP)

sns.scatterplot(y='Life expectancy at birth (years)', x='log_GDP', data=data, hue='Country')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None               Year  Life expectancy at birth (years)           GDP
# count    96.000000                         96.000000  9.600000e+01
# mean   2007.500000                         72.789583  3.880499e+12
# std       4.633971                         10.672882  5.197561e+12
# min    2000.000000                         44.300000  4.415703e+09
# 25%    2003.750000                         74.475000  1.733018e+11
# ...
